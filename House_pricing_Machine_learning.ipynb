# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
data=pd.read_csv("C:/Users/Veena/Downloads/archive/data_house.csv")
data
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0         3       1.00
# 1               1  6414100192  20141209T000000  538000.0         3       2.25
# 2               2  5631500400  20150225T000000  180000.0         2       1.00
# 3               3  2487200875  20141209T000000  604000.0         4       3.00
# 4               4  1954400510  20150218T000000  510000.0         3       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
# ...

# %%
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 21608         1530      1131     3.0           0  ...      8        1530
# 21609         2310      5813     2.0           0  ...      8        2310
# 21610         1020      1350     2.0           0  ...      7        1020
# 21611         1600      2388     2.0           0  ...      8        1600
# 21612         1020      1076     2.0           0  ...      7        1020
#
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>,
#         <Axes: title={'center': 'yr_built'}>],
#        [<Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>],
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.370842      2.114757
# std     6239.28002  2.876566e+09  3.671272e+05      0.930062      0.770163
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
x=data["sqft_living"]
x.head()
# Out:
# 0    1180
# 1    2570
# 2     770
# 3    1960
# 4    1680
# Name: sqft_living, dtype: int64

# %%
y=data["price"]
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
#          ...
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# Name: sqft_living, Length: 21613, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
a=data["sqft_living"].values
b=data["price"].values
print(type(a),type(b))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
a
# Out:
# array([1180, 2570,  770, ..., 1020, 1600, 1020], dtype=int64)

# %%
b
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
data.corr()
# Out:
# C:\Users\Veena\AppData\Local\Temp\ipykernel_8528\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                Unnamed: 0        id     price  bedrooms  bathrooms  \
# Unnamed: 0       1.000000  0.006718  0.027372  0.010794   0.107334
# id               0.006718  1.000000 -0.016762  0.001286   0.005160
# price            0.027372 -0.016762  1.000000  0.308350   0.525138
# bedrooms         0.010794  0.001286  0.308350  1.000000   0.515884
# bathrooms        0.107334  0.005160  0.525138  0.515884   1.000000
# sqft_living      0.044717 -0.012258  0.702035  0.576671   0.754665
# sqft_lot        -0.026877 -0.132109  0.089661  0.031703   0.087740
# floors           0.179138  0.018525  0.256794  0.175429   0.500653
# waterfront      -0.007611 -0.002721  0.266369 -0.006582   0.063744
# ...

# %%
plt.scatter(x,y)
plt.title("House Pricing")
plt.xlabel("square feet")
plt.ylabel("Price")
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
data.shape
# Out:
# (21613, 22)

# %%
xtrain.shape
# Out:
# (17290,)

# %%
xtrain
# Out:
# 6325     1780
# 13473    1000
# 17614    1080
# 16970    2090
# 20868    1741
#          ...
# 11964    1000
# 21575    3087
# 5390     2120
# 860       380
# 15795    3130
# Name: sqft_living, Length: 17290, dtype: int64

# %%
xtest.shape
# Out:
# (4323,)

# %%
xtest
# Out:
# 735      2070
# 2830     2900
# 4106     3770
# 16218    4560
# 19964    2550
#          ...
# 13674    1250
# 20377    2830
# 8805     2434
# 10168    2250
# 2522     2570
# Name: sqft_living, Length: 4323, dtype: int64

# %%
ytrain.shape
# Out:
# (17290,)

# %%
ytest.shape
# Out:
# (4323,)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print('Training Started.......\n')
print()
lin_reg.fit(xtrain,ytrain)
print()
print('Training Completed.....\n')
print()
#test the data
print('Testing invoked......\n')
ypred=lin_reg.predict(x_test)
print('Predicted Total Payment \n',ypred)
print('\n Testing is also completed....\n')
# Out:
# Training Started.......
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 5
#       3 print('Training Started.......\n')
#       4 print()
# ----> 5 lin_reg.fit(xtrain,ytrain)
#       6 print()
#       7 print('Training Completed.....\n')
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %%
from sklearn.linear_model import LinearRegression
x=data['sqft_living'].values.reshape(-1,1)
y=data['price'].values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
linearreg = LinearRegression()
linearreg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
#test the data
ypred=linearreg.predict(xtest)
print('Predicted Results:\n',ypred)
# Out:
# Predicted Results:
#  [ 613150.08006449  549455.43767992 1064320.46362182 ...  709753.62101441
#   660921.06185291  745847.251699  ]

# %%
diff=ytest-ypred
diff
# Out:
# array([-248150.08006449,  315544.56232008,  -26320.46362182, ...,
#        -424753.62101441,  -55921.06185291, -389347.251699  ])

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,explained_variance_score
print('R square:',r2_score(ytest,ypred))
print('Mean Absolute Error:', mean_absolute_error(ytest,ypred))
print('Mean Square Error:', mean_squared_error(ytest,ypred))
print('Variance Score', explained_variance_score(ytest,ypred))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(ytest,ypred)))
# Out:
# R square: 0.37561381124490334
# Mean Absolute Error: 194207.80752424005
# Mean Square Error: 94392651194.5846
# Variance Score 0.37607801083589487
# Root Mean Square Error: 307233.870519812

# %%
#visualize the training dataset
plt.scatter(xtrain,ytrain,color='Red')
plt.plot(xtrain,linearreg.predict(xtrain),color='Blue')
plt.title('House Pricing(training dataset)')
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.show()

# %%
#visualize the testing dataset
plt.scatter(xtest,ytest,color='Red')
plt.plot(xtest,linearreg.predict(xtest),color='Blue')
plt.title('House Pricing(testing dataset)')
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
#load the dataset
data=pd.read_csv("C:/Users/Veena/Downloads/archive/data_house.csv")
data
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0         3       1.00
# 1               1  6414100192  20141209T000000  538000.0         3       2.25
# 2               2  5631500400  20150225T000000  180000.0         2       1.00
# 3               3  2487200875  20141209T000000  604000.0         4       3.00
# 4               4  1954400510  20150218T000000  510000.0         3       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
# ...

# %%
#missing values
data.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
sns.pairplot(data)

# %%
x=data[['bedrooms','sqft_living','bathrooms']]
y=data['price']

# %%
import sklearn
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y, test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
#train the model
reg.fit(xtrain,ytrain)
test=reg.predict(xtest)

# %%
print("Predicted test results:",test)
# Out:
# Predicted test results: [676070.09979181 406400.1715258  661618.00557459 ... 521972.73515719
#  956841.56724078 704770.18238118]

# %%
ytest
# Out:
# 19836    285000.0
# 10442    239950.0
# 20548    460000.0
# 11014    397500.0
# 4138     545000.0
#            ...
# 5625     235000.0
# 8698     500000.0
# 9786     850000.0
# 2784     340000.0
# 9552     788000.0
# Name: price, Length: 4323, dtype: float64

# %%
#Actual value and the predicted value
diff =pd.DataFrame({'Actual value': ytest,'Predicted value':test})
diff
# Out:
#        Actual value  Predicted value
# 19836      285000.0    676070.099792
# 10442      239950.0    406400.171526
# 20548      460000.0    661618.005575
# 11014      397500.0    365890.682232
# 4138       545000.0    458358.376899
# ...             ...              ...
# 5625       235000.0    238441.680947
# 8698       500000.0    332066.631937
# 9786       850000.0    521972.735157
# 2784       340000.0    956841.567241
# 9552       788000.0    704770.182381
#
# [4323 rows x 2 columns]

# %%
diff.head()
# Out:
#        Actual value  Predicted value
# 19836      285000.0    676070.099792
# 10442      239950.0    406400.171526
# 20548      460000.0    661618.005575
# 11014      397500.0    365890.682232
# 4138       545000.0    458358.376899

# %%
dif=ytest-test
dif
# Out:
# 19836   -391070.099792
# 10442   -166450.171526
# 20548   -201618.005575
# 11014     31609.317768
# 4138      86641.623101
#              ...
# 5625      -3441.680947
# 8698     167933.368063
# 9786     328027.264843
# 2784    -616841.567241
# 9552      83229.817619
# Name: price, Length: 4323, dtype: float64

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
print('R square:',r2_score(ytest,test))
print('Mean Absolute Error:', mean_absolute_error(ytest,test))
print('Mean Square Error:', mean_squared_error(ytest,test))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(ytest,test)))
# Out:
# R square: 0.5305205951352602
# Mean Absolute Error: 169171.5528966655
# Mean Square Error: 63271318344.59471
# Root Mean Square Error: 251537.90637713973

# %%
sns.pairplot(data, x_vars=['bedrooms','sqft_living','bathrooms'], y_vars='price', height=4, aspect=1, kind='scatter')
plt.show()

# %%
plt.figure(figsize=(17,9))
sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=1)
# Out:
# C:\Users\Veena\AppData\Local\Temp\ipykernel_8528\4169577357.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=1)
# <Axes: >
